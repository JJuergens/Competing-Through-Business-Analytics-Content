# %% [markdown]
# # M2: Basic Graphing Assignment | Jackie Juergens | 7/14/19

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ### Filename: OpiodsVA.csv
# Do opioid overdoes tend to be associated with less affluent areas—that is, areas where families have lower incomes?
#
# Some people who start with opioid addictions are reported to transition to heroin use. What is the relationship in Virginia counties between opioid overdoses and heroin overdoses?

# %%
dfOp = pd.read_csv('C:/Users/tetrauja/Desktop/W&M/CTBA/M2/OpidsVA.csv')

# %%
dfOp.head()
# Out:
#    FIPSCode CountyName  FFHO-Rate  FPOO-Rate  HIV-Rate  MedianHouseholdIncome
# 0     51001   Accomack       12.1       12.1       3.0                  39040
# 1     51003  Albemarle        0.9        0.9       2.8                  73132
# 2     51005  Alleghany        6.4       12.8       6.4                  47037
# 3     51007     Amelia        7.7        0.0       7.7                  56172
# 4     51009    Amherst        3.2        6.3       6.3                  46497

# %%
fig,ax = plt.subplots()

plt.scatter(dfOp['MedianHouseholdIncome'],dfOp['FPOO-Rate'], alpha = .5, c = 'b')

fig.suptitle('Relationship between Opioid Overdose Rate and Household Income')    
ax.xaxis.set_label_text('Median Household Income')
ax.yaxis.set_label_text('Opiod Overdoses per 100,000 Residents')
fig.set_size_inches(7,5)
plt.show()

# %% [markdown]
# A scatter plot best represents the relationship between household income and the number of opioid overdoses because they are a number of independent data points and we are looking for trends.

# %%
fig,ax = plt.subplots()

plt.scatter(dfOp['FFHO-Rate'],dfOp['FPOO-Rate'], alpha = .5, c = 'g')

fig.suptitle('Relationship between Opioid and Herion Overdose Rates')    
ax.xaxis.set_label_text('Herion Overdoses per 100,000 Residents')
ax.yaxis.set_label_text('Opiod Overdoses per 100,000 Residents')
fig.set_size_inches(7,5)
plt.show()

# %% [markdown]
# A scatter plot is also the best visual to show the relationship between the opioid and herion overdoes rates because they are a lot of independent data points.

# %% [markdown]
# ## Filename: presidents.csv
# Which states are associated with the greatest number of United States presidents interms of the presidents’ birthplaces?

# %%
dfPres = pd.read_csv('C:/Users/tetrauja/Desktop/W&M/CTBA/M2/presidents.csv')

# %%
dfPres.head()
# Out:
#                 Name             Location          State
# 0  George Washington  Westmoreland County       Virginia
# 1         John Adams            Braintree  Massachusetts
# 2   Thomas Jefferson             Shadwell       Virginia
# 3      James Madison          Port Conway       Virginia
# 4       James Monroe          Monroe Hall       Virginia

# %%
fig,ax = plt.subplots()
ax.bar(dfPres['State'][:12].unique(),dfPres['State'][:12].value_counts())

fig.suptitle('State Birthplace of Most US Presidents')    
ax.xaxis.set_label_text('# Presidents Birthplace')
ax.yaxis.set_label_text('State')
fig.set_size_inches(10,6)
plt.show()

# %% [markdown]
# A bar chart is the best visualization to show the number of occurances for something within distinct buckets (i.e. states).

# %% [markdown]
# ## Filename: TOTALNSA.csv
# How have vehicle sales in the United States varied over time?

# %%
dfCars = pd.read_csv('C:/Users/tetrauja/Desktop/W&M/CTBA/M2/TOTALNSA.csv')

# %%
dfCars = set_index

from pandas import Series
dfCars.head()
# Out:
#          DATE  TOTALNSA
# 0  1976-01-01     885.2
# 1  1976-02-01     994.7
# 2  1976-03-01    1243.6
# 3  1976-04-01    1191.2
# 4  1976-05-01    1203.2

# %%
fig,ax = plt.subplots()

ax.plot(dfCars['DATE'], dfCars['TOTALNSA'])
fig.suptitle('Vehicle Sales in the US 1976-2018')    
ax.xaxis.set_label_text('Date')
ax.yaxis.set_label_text('# Cars Sold')

plt.xticks(dfCars['DATE'], rotation='vertical')
import matplotlib.ticker as ticker
ax.xaxis.set_major_locator(ticker.MultipleLocator(10))   #Thanks to Shannon!

fig.set_size_inches(15,8)
plt.show()

# %% [markdown]
# Time series should be displayed as a plotted line chart to show changes over time.
